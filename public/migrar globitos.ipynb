# %%
import sys
import xlsxwriter
import pandas as pd
import sys
import psycopg2
import os
from dotenv import load_dotenv
from datetime import date
import numpy as np
today = date.today()
load_dotenv()

#configurar la conexion a la base de datos
DB_USERNAME = os.getenv('DB_USERNAME')
DB_DATABASE = os.getenv('DB_DATABASE')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_PORT = os.getenv('DB_PORT')
DB_HOST=os.getenv('DB_HOST')
# Conectar a DB
# Conectar a PostgreSQL
try:
    cnx = psycopg2.connect(
        user=DB_USERNAME,
        password=DB_PASSWORD,
        host=DB_HOST,
        port=DB_PORT,
        database=DB_DATABASE
    )
    print("Conexión exitosa")
except psycopg2.Error as e:
    print("Ocurrió un error al conectar a la base de datos:", e)
cursor=cnx.cursor()
# Out:
# Conexión exitosa

# %%
cnx.close()

# %%
data=pd.read_excel('GLOBITOS.xlsx')

# %%
cnx.close()
import sys
import xlsxwriter
import pandas as pd
import sys
import psycopg2
import os
from dotenv import load_dotenv
from datetime import date
import numpy as np
today = date.today()
load_dotenv()

#configurar la conexion a la base de datos
DB_USERNAME = os.getenv('DB_USERNAME')
DB_DATABASE = os.getenv('DB_DATABASE')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_PORT = os.getenv('DB_PORT')
DB_HOST=os.getenv('DB_HOST')
# Conectar a DB
# Conectar a PostgreSQL
try:
    cnx = psycopg2.connect(
        user=DB_USERNAME,
        password=DB_PASSWORD,
        host=DB_HOST,
        port=DB_PORT,
        database=DB_DATABASE
    )
    print("Conexión exitosa")
except psycopg2.Error as e:
    print("Ocurrió un error al conectar a la base de datos:", e)
cursor=cnx.cursor()

for i in range(len(data)):
    info=data['help_info'].values[i]
    if(pd.notna(info)):
        info=info.replace("'","´")
        print(query)
        query=f"update options set help_info='{info}' where reactivo='{data['reactivo'].values[i]}' and clave='{data['clave'].values[i]}'"
        cursor.execute(query)
# Out:
# Conexión exitosa
# update options set help_info="Sector Público: Director general de una secretaría de estado, jefe de departamento en un ayuntamiento, director de una escuela pública.
# Sector Privado: Director ejecutivo (CEO) de una empresa, gerente general de una sucursal, jefe de área de producción.
# Organizaciones No Gubernamentales: Director de una fundación, coordinador de un programa social." where reactivo='ocupacion' and clave='45'
# update options set help_info='Sector Público: Director general de una secretaría de estado, jefe de departamento en un ayuntamiento, director de una escuela pública.
# Sector Privado: Director ejecutivo (CEO) de una empresa, gerente general de una sucursal, jefe de área de producción.
# Organizaciones No Gubernamentales: Director de una fundación, coordinador de un programa social.' where reactivo='ocupacion' and clave='45'
# ...

# %%
data['help_info'].unique()
# Out:
# array([nan,
#        'Sector Público: Director general de una secretaría de estado, jefe de departamento en un ayuntamiento, director de una escuela pública.\nSector Privado: Director ejecutivo (CEO) de una empresa, gerente general de una sucursal, jefe de área de producción.\nOrganizaciones No Gubernamentales: Director de una fundación, coordinador de un programa social.',
#        'Salud: Médico especialista (cardiólogo, pediatra), enfermero general, técnico en radiología.\nIngeniería: Ingeniero civil, ingeniero en sistemas computacionales, técnico en mantenimiento industrial.\nEducación: Profesor universitario, maestro de educación básica, pedagogo.\nCiencias Sociales y Humanidades: Abogado, psicólogo clínico, sociólogo, historiador.\nArte y Diseño: Arquitecto, diseñador gráfico, músico profesional.',
#        'Secretario/a ejecutivo/a, asistente administrativo, recepcionista, cajero/a, capturista de datos, archivista, oficinista.',
# ...

# %%
cnx.commit()

# %%
reactivos=pd.read_sql("select * from reactivos where section like 'esp%'",cnx)
# Out:
# c:\Users\fgonzalez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# for i in range(len(reactivos)):
#     type='integer'
#     if(reactivos['type'].values[i]=='text'):
#
#         type='varchar(255)'
#     print(f"ALTER TABLE respuestas_continua ADD COLUMN {reactivos['clave'].values[i]} {type};" )

# %%
for i in range(len(reactivos)):
    type='integer'
    if(reactivos['type'].values[i]=='text'):
        type='varchar(255)'
    if(reactivos['type'].values[i]!='multiple_option'):
        print(f"ALTER TABLE respuestas_especialidad ADD COLUMN {reactivos['clave'].values[i]} {type};" )
# Out:
# ALTER TABLE respuestas_especialidad ADD COLUMN esp9 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp8 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp7 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp11 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp5 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp17 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp16 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp15 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp14 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp13 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp19 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp6 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp12 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp18 integer;
# ALTER TABLE respuestas_especialidad ADD COLUMN esp21 integer;
# ...
